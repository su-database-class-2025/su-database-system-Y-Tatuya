# %%
import os
from sqlalchemy import create_engine
import pandas as pd
import geopandas as gpd
import numpy as np
import folium
pd.set_option('display.max_columns', 100)

def query_geopandas(sql, db):
    """
    Executes a SQL query on a postGIS and returns the result as a GeoPandas GeoDataFrame.

    Args:
        sql (str): The SQL query to execute.
        db (str): The name of the PostgreSQL database to connect to.

    Returns:
        geopandas.GeoDataFrame: The result of the SQL query as a GeoPandas GeoDataFrame.
    """
    DATABASE_URL = 'postgresql://postgres:postgres@postgis_container:5432/{}'.format(db)
    conn = create_engine(DATABASE_URL)
    query_result_gdf = gpd.GeoDataFrame.from_postgis(
        sql, conn, geom_col='way') #geom_col='way' when using osm_kanto, geom_col='geom' when using gisdb
    return query_result_gdf

sql = "WITH \
    pop19 AS ( \
        SELECT p.name, d.population, p.geom  \
        FROM pop AS d \
        INNER JOIN pop_mesh AS p \
            ON p.name = d.mesh1kmid \
        WHERE d.dayflag='0' AND \
            timezone='0' AND \
            d.year='2019' AND \
            d.month='04'\
    ),\
    pop20 AS (\
        SELECT p.name, d.population, p.geom\
            FROM pop AS d\
            INNER JOIN pop_mesh AS p \
                ON p.name = d.mesh1kmid\
            WHERE d.dayflag='0' AND \
                d.timezone='0' AND \
                d.year='2020' AND \
                d.month='04'\
    )\
    SELECT DISTINCT ON (pt.name)\
        poly.name_1 AS pref_name, \
        pt.name AS station_name, \
        (CAST(p20.population AS FLOAT) - CAST(p19.population AS FLOAT)) / CAST(p19.population AS FLOAT) AS growth, \
        pt.way \
    FROM planet_osm_point AS pt \
    INNER JOIN adm2 AS poly ON st_within(pt.way, st_transform(poly.geom, 3857)) \
    INNER JOIN pop19 AS p19 ON st_within(st_transform(pt.way, 4326), p19.geom) \
    INNER JOIN pop20 AS p20 ON p19.name = p20.name \
    WHERE pt.railway='station' AND \
        poly.name_1 ='Saitama' AND \
        p19.population > 0 \
    ORDER BY pt.name, growth ASC \
    LIMIT 10;"

def display_interactive_map(gdf):
    if gdf.crs != 'EPSG:4326':
        gdf = gdf.to_crs(epsg=4326)
    # Create a base map
    m = folium.Map(location=[35.8616, 139.6455], zoom_start=12)  # You can modify the location as per your dataset

    # Add data points to the map
    for _, row in gdf.iterrows():
        coords = (row['way'].y, row['way'].x)
        folium.Marker(location=coords, popup=row['station_name']).add_to(m)

    return m

out = query_geopandas(sql,'gisdb')
map_display = display_interactive_map(out)
print(out[['pref_name', 'station_name', 'growth']])
display(map_display)
# Out:
#   pref_name station_name    growth
# 0   Saitama      さいたま新都心 -0.619451
# 1   Saitama        せんげん台  0.148507
# 2   Saitama    ソシオ流通センター -0.060159
# 3   Saitama         つきのわ  0.148454
# 4   Saitama     ハートフルランド -0.945013
# 5   Saitama      ひろせ野鳥の森 -0.129691
# 6   Saitama        ふかや花園 -0.347749
# 7   Saitama         ふじみ野  0.079294
# 8   Saitama         みずほ台  0.140576
# 9   Saitama        みなみ寄居  0.076220
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1f80798f91b7d1a3a08e3a12531cc796 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1f80798f91b7d1a3a08e3a12531cc796&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1f80798f91b7d1a3a08e3a12531cc796 = L.map(
#                 &quot;map_1f80798f91b7d1a3a08e3a12531cc796&quot;,
#                 {
#                     center: [35.8616, 139.6455],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5ab8a4626325656b9e1279b33016fffc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5ab8a4626325656b9e1279b33016fffc.addTo(map_1f80798f91b7d1a3a08e3a12531cc796);
#
#
#             var marker_aefd9145b486a86b28379ea1a990134b = L.marker(
#                 [35.89363739972513, 139.6339481],
#                 {
# }
#             ).addTo(map_1f80798f91b7d1a3a08e3a12531cc796);
#
#
#         var popup_802cd326bd63fd741ed4df7c04934725 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7059852f0ee0a58505599a6dbb32f8e5 = $(`&lt;div id=&quot;html_7059852f0ee0a58505599a6dbb32f8e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;さいたま新都心&lt;/div&gt;`)[0];
#                 popup_802cd326bd63fd741ed4df7c04934725.setContent(html_7059852f0ee0a58505599a6dbb32f8e5);
#
#
#
#         marker_aefd9145b486a86b28379ea1a990134b.bindPopup(popup_802cd326bd63fd741ed4df7c04934725)
#         ;
#
#
#
#
#             var marker_1adced508a9f45ac5cca1159f8ccd2f2 = L.marker(
#                 [35.93585609972923, 139.7744756],
#                 {
# }
#             ).addTo(map_1f80798f91b7d1a3a08e3a12531cc796);
#
#
#         var popup_a10b412c5c8ba6e2609225f51fa146ef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7fe37d6c832b5b0378880a0e89986bdf = $(`&lt;div id=&quot;html_7fe37d6c832b5b0378880a0e89986bdf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;せんげん台&lt;/div&gt;`)[0];
#                 popup_a10b412c5c8ba6e2609225f51fa146ef.setContent(html_7fe37d6c832b5b0378880a0e89986bdf);
#
#
#
#         marker_1adced508a9f45ac5cca1159f8ccd2f2.bindPopup(popup_a10b412c5c8ba6e2609225f51fa146ef)
#         ;
#
#
#
#
#             var marker_569b3313e0525d819b73386695d78e5d = L.marker(
#                 [36.13647789974938, 139.4244068],
#                 {
# }
#             ).addTo(map_1f80798f91b7d1a3a08e3a12531cc796);
#
#
#         var popup_6844649d871baab6ad49efd758a8bbfa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_081c7d5636effa883b3856f8a4d59b4f = $(`&lt;div id=&quot;html_081c7d5636effa883b3856f8a4d59b4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ソシオ流通センター&lt;/div&gt;`)[0];
#                 popup_6844649d871baab6ad49efd758a8bbfa.setContent(html_081c7d5636effa883b3856f8a4d59b4f);
#
#
#
#         marker_569b3313e0525d819b73386695d78e5d.bindPopup(popup_6844649d871baab6ad49efd758a8bbfa)
#         ;
#
#
#
#
#             var marker_f7c0230821982a4ee07c21d404bc5551 = L.marker(
#                 [36.04349289973988, 139.34539720000004],
#                 {
# }
#             ).addTo(map_1f80798f91b7d1a3a08e3a12531cc796);
#
#
#         var popup_d2df205ecc70b2609001f4d7c82364e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0ccc125886bde1ac72940e638597fbf0 = $(`&lt;div id=&quot;html_0ccc125886bde1ac72940e638597fbf0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;つきのわ&lt;/div&gt;`)[0];
#                 popup_d2df205ecc70b2609001f4d7c82364e8.setContent(html_0ccc125886bde1ac72940e638597fbf0);
#
#
#
#         marker_f7c0230821982a4ee07c21d404bc5551.bindPopup(popup_d2df205ecc70b2609001f4d7c82364e8)
#         ;
#
#
#
#
#             var marker_24f7e8557bd14a3f55b004913afe8a17 = L.marker(
#                 [36.02143729973768, 139.7118592],
#                 {
# }
#             ).addTo(map_1f80798f91b7d1a3a08e3a12531cc796);
#
#
#         var popup_0caf23b02962986b1fd6a745f349e565 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a71f838f58fcc3c842f2f08d2c504e1c = $(`&lt;div id=&quot;html_a71f838f58fcc3c842f2f08d2c504e1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ハートフルランド&lt;/div&gt;`)[0];
#                 popup_0caf23b02962986b1fd6a745f349e565.setContent(html_a71f838f58fcc3c842f2f08d2c504e1c);
